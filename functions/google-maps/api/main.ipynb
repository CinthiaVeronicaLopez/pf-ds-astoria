# %%
import os
import requests
import pandas as pd
import pyarrow as pa
import pyarrow.parquet as pq

# %%
import yaml

with open('.env.yaml', 'r') as file:
    env_vars = yaml.safe_load(file)

# %%
# CONSTANTES
# CLIENT_ID = env_vars["Maps_CLIENT_ID"]
API_KEY = env_vars["YELP_API_KEY"]
GCP_PROJECT = env_vars["GCP_PROJECT"]
PARAMS="location=astoria&limit=50"
TABLE_ID = "metadata-sites"
DATASET_ID = "astoria"

# %%
# Realizar la solicitud HTTP
def request_api(url, params):    
    url = f"{url}?{params}&key={API_KEY}"
    response = requests.get(url)
    return response.json()

# %%
# Obtener localización de un estado
def get_state_metadata(state):
    url="https://maps.googleapis.com/maps/api/geocode/json"
    params=f"address={state}"
    response_json = request_api(url, params)
    result = response_json["results"][0]
    return result

geocoding = get_state_metadata("Florida")
location = f"{geocoding['geometry']['location']['lat']},{geocoding['geometry']['location']['lng']}"
location
# Out:
# '27.6648274,-81.5157535'

# %%
# Obtener lugares cercanos
def get_nearby_places(location, radius=50000, place_type='business'):
    url="https://maps.googleapis.com/maps/api/place/nearbysearch/json"    
    # fields = 'place_id,rating,user_ratings_total'
    params=f"location={location}&radius={radius}&type={place_type}"#&fields={fields}"
    places_response = request_api(url, params)
    result = places_response['results']
    return result

places = get_nearby_places(location)
places
# Out:
# [{'geometry': {'location': {'lat': 27.5958672, 'lng': -81.5061862},
#    'viewport': {'northeast': {'lat': 27.63315792242184,
#      'lng': -81.47286495262327},
#     'southwest': {'lat': 27.57236998615755, 'lng': -81.53922891092547}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/geocode-71.png',
#   'icon_background_color': '#7B9EB0',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#   'name': 'Avon Park',
#   'photos': [{'height': 1600,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103339891864974358915">ruth Smith</a>'],
#     'photo_reference': 'AcJnMuFj_BBIu5dORaq50iOk2sR-ry0bJk4nbfCEgV_txI4nhh2t6owdML4KAXAzNO8r7psQmegLlrxPpddu9td-weAPMenGj_93dHTob_qwmFBCPetllxMlzS4tFg4d_u4Kst81ERUjBDOhelQJnqb6Nqso8HqmjHppeO5CplpuYCSkWQL3',
#     'width': 747}],
#   'place_id': 'ChIJV-gnG45V3IgRSDUQcb3C0hw',
#   'reference': 'ChIJV-gnG45V3IgRSDUQcb3C0hw',
#   'scope': 'GOOGLE',
#   'types': ['locality', 'political'],
#   'vicinity': 'Avon Park'},
#  {'business_status': 'CLOSED_TEMPORARILY',
#   'geometry': {'location': {'lat': 27.599535, 'lng': -81.5127921},
#    'viewport': {'northeast': {'lat': 27.6008853302915,
#      'lng': -81.5115995197085},
#     'southwest': {'lat': 27.5981873697085, 'lng': -81.5142974802915}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'icon_background_color': '#7B9EB0',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#   'name': 'Kevin Sherin, MD',
#   'permanently_closed': True,
#   'place_id': 'ChIJIS7C6UF854gRs6HvPDkbv-o',
#   'plus_code': {'compound_code': 'HFXP+RV Avon Park, FL, USA',
#    'global_code': '76VWHFXP+RV'},
#   'rating': 5,
#   'reference': 'ChIJIS7C6UF854gRs6HvPDkbv-o',
#   'scope': 'GOOGLE',
#   'types': ['doctor', 'point_of_interest', 'health', 'establishment'],
#   'user_ratings_total': 4,
#   'vicinity': '1006 West Pleasant Street, Avon Park'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 27.5945129, 'lng': -81.4877728},
#    'viewport': {'northeast': {'lat': 27.5960522802915,
#      'lng': -81.4864277197085},
#     'southwest': {'lat': 27.5933543197085, 'lng': -81.48912568029151}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/school-71.png',
#   'icon_background_color': '#7B9EB0',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/school_pinlet',
#   'name': 'Avon Park High School',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 2988,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101131315851983657354">Olga Baez</a>'],
#     'photo_reference': 'AcJnMuF0CQRLiy0i4ExXRqZqF7A4L_1RlWj3dpxpzgCqViscOLNT3KfEzY4hE2fxMFu-bvv3zNIm8OizkDHuMKPk4ZkMNWtJj_qIg_r_YU5AdHX_aUZtc_TTGIlejIQ52g2nFyGY7ifXbEOAHeS_5uXvJnA4oyZGEqhkPDS9Wx9RBYW4WJOi',
#     'width': 5312}],
#   'place_id': 'ChIJcYhIUcdV3IgRKQhEFT6RBZA',
#   'plus_code': {'compound_code': 'HGV6+RV Avon Park, FL, USA',
#    'global_code': '76VWHGV6+RV'},
#   'rating': 3.6,
#   'reference': 'ChIJcYhIUcdV3IgRKQhEFT6RBZA',
#   'scope': 'GOOGLE',
#   'types': ['secondary_school',
#    'point_of_interest',
#    'school',
#    'establishment'],
#   'user_ratings_total': 11,
#   'vicinity': '700 East Main Street, Avon Park'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 27.5969143, 'lng': -81.5149472},
#    'viewport': {'northeast': {'lat': 27.59826153029151,
#      'lng': -81.51353596970849},
#     'southwest': {'lat': 27.5955635697085, 'lng': -81.5162339302915}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#   'icon_background_color': '#4B96F3',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#   'name': 'JNK Auto Supply Inc',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113170419890360247733">John Ferron</a>'],
#     'photo_reference': 'AcJnMuHB__4K1834kCWSBKVss-OyWhIcTk3V5BtLXwOvUnqd0xgf6GzCXBPNhQg4Undn5ORyhF4yOXXo4mcDc6QH3fgOG_uM9-2PgAPZAUOvwozh_s82VU-mjEOX3SPP9sobGFVAOherEeQbmnkBnFn1D_8ctjAMa30Hv6l6pYKf2ot-jyvH',
#     'width': 4032}],
#   'place_id': 'ChIJv5WklJJV3IgRQPjNGzVT53o',
#   'plus_code': {'compound_code': 'HFWP+Q2 Avon Park, FL, USA',
#    'global_code': '76VWHFWP+Q2'},
#   'rating': 4.6,
#   'reference': 'ChIJv5WklJJV3IgRQPjNGzVT53o',
#   'scope': 'GOOGLE',
#   'types': ['car_repair', 'point_of_interest', 'store', 'establishment'],
#   'user_ratings_total': 78,
#   'vicinity': '195 US Highway 27 North, Avon Park'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 27.6183131, 'lng': -81.5117685},
#    'viewport': {'northeast': {'lat': 27.6197439302915,
#      'lng': -81.5105341197085},
#     'southwest': {'lat': 27.6170459697085, 'lng': -81.5132320802915}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'icon_background_color': '#7B9EB0',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#   'name': 'Peace River Center',
#   'place_id': 'ChIJB1WyCk5X3IgR0KLuOe5C6y0',
#   'plus_code': {'compound_code': 'JF9Q+87 Avon Park, FL, USA',
#    'global_code': '76VWJF9Q+87'},
#   'rating': 3.4,
#   'reference': 'ChIJB1WyCk5X3IgR0KLuOe5C6y0',
#   'scope': 'GOOGLE',
#   'types': ['point_of_interest', 'health', 'establishment'],
#   'user_ratings_total': 5,
#   'vicinity': '950 County Road 17A West, Avon Park'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 27.5700134, 'lng': -81.51169240000002},
#    'viewport': {'northeast': {'lat': 27.5714427302915,
#      'lng': -81.5103810697085},
#     'southwest': {'lat': 27.5687447697085, 'lng': -81.51307903029151}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/school-71.png',
#   'icon_background_color': '#7B9EB0',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/school_pinlet',
#   'name': 'South Florida State College',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 2240,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113177902068854228968">South Florida State College</a>'],
#     'photo_reference': 'AcJnMuFt5ZDGete8ILd3JJ_EhYp4FxfOic90cAbILbHNkxKOBp5iwSAjv07wfu98W8wReENtERlScLTeJ8xFsy3Dxl79TWY304PzfdbeD_yEhlOUvQn5iQ6RdTLP58Bh2CEABNno8-iLebUQYLI3_LgxRyA1f4zkVKKfGaVNDxh7mgfF9g09',
#     'width': 3360}],
#   'place_id': 'ChIJK7dXAwdW3IgRrbkiT8drUtE',
#   'plus_code': {'compound_code': 'HFCQ+28 Avon Park, FL, USA',
#    'global_code': '76VWHFCQ+28'},
#   'rating': 4.5,
#   'reference': 'ChIJK7dXAwdW3IgRrbkiT8drUtE',
#   'scope': 'GOOGLE',
#   'types': ['university', 'point_of_interest', 'school', 'establishment'],
#   'user_ratings_total': 110,
#   'vicinity': '600 West College Drive, Avon Park'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 27.7331957, 'lng': -81.5732263},
#    'viewport': {'northeast': {'lat': 27.7346979802915,
#      'lng': -81.57159756970849},
#     'southwest': {'lat': 27.7320000197085, 'lng': -81.57429553029151}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Subway',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 3264,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107146081807393925039">Dalton Broadus</a>'],
#     'photo_reference': 'AcJnMuFi63is9w6uwL1uBLxVfyMDJoM8lKSehQjv9FGmB8Dtez2PtyN6P5M_VJ3BkL77ibrQu6b_JuVBX8OxUHv5EKZdCx6cBYkp1ChioDGmLvpDJMZv8RmPisyTrJ5nkB_WI9fCNLaJcCFmTSYxVu1C8-QH8GXvZr4bMQlqhmea_xpFRXMT',
#     'width': 2448}],
#   'place_id': 'ChIJBQ0UKRcB3YgRajNYh6FWy5Q',
#   'plus_code': {'compound_code': 'PCMG+7P Frostproof, FL, USA',
#    'global_code': '76VWPCMG+7P'},
#   'price_level': 1,
#   'rating': 3.7,
#   'reference': 'ChIJBQ0UKRcB3YgRajNYh6FWy5Q',
#   'scope': 'GOOGLE',
#   'types': ['meal_takeaway',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'user_ratings_total': 90,
#   'vicinity': '7030 US Highway 27, Frostproof'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 27.6281557, 'lng': -81.51708730000001},
#    'viewport': {'northeast': {'lat': 27.6296114802915,
#      'lng': -81.5157376197085},
#     'southwest': {'lat': 27.62691351970849, 'lng': -81.51843558029151}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'icon_background_color': '#7B9EB0',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#   'name': 'Royal Care of Avon Park',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 720,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108127722674588672114">Royal Care of Avon Park</a>'],
#     'photo_reference': 'AcJnMuEoA8yC3WqkG5M3Umc_oWQ2WVqkz87JOlWDx6yX_wRliA7fEJp8yukHJWtTznt6sHGOSDR7t3Tv2ldn8vR0MWfOH1LCEiNM2Lq8cW-l3p01unzIFGDbo43pOdSUYpAyErC4XB_WGrchGWBF-MN-c84RhYKBOKH0GZElOtGDM7DWBgFR',
#     'width': 1280}],
#   'place_id': 'ChIJOULHoof_3IgRzpps_TBXkMI',
#   'plus_code': {'compound_code': 'JFHM+75 Avon Park, FL, USA',
#    'global_code': '76VWJFHM+75'},
#   'rating': 3.2,
#   'reference': 'ChIJOULHoof_3IgRzpps_TBXkMI',
#   'scope': 'GOOGLE',
#   'types': ['point_of_interest', 'health', 'establishment'],
#   'user_ratings_total': 21,
#   'vicinity': '1213 West Stratford Road, Avon Park'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 27.5959798, 'lng': -81.5017311},
#    'viewport': {'northeast': {'lat': 27.5972719302915,
#      'lng': -81.5003832197085},
#     'southwest': {'lat': 27.5945739697085, 'lng': -81.50308118029152}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'icon_background_color': '#909CE1',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#   'name': 'Jacaranda Hotel',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 1333,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107176415304075023071">Jacaranda Hotel</a>'],
#     'photo_reference': 'AcJnMuEi4m2DaiLBUG1Q37Lkp0YpaZjhsoggWbdN-dyhJpnoj8K-bYpkCEZ5e_yO6DlkfABTDu_j5oWp8v_ErwVYSIBVGm1grJ5aphtT57u4PQ62vOZsv-ReqiF7R7KKg0vB77SIZALyO9x8LbAObt7iCPsCxhIcVi6RdtJXZ6Yg4vxnXQ2h',
#     'width': 2048}],
#   'place_id': 'ChIJ5carHpNV3IgRg2sUDm8rhHY',
#   'plus_code': {'compound_code': 'HFWX+98 Avon Park, FL, USA',
#    'global_code': '76VWHFWX+98'},
#   'rating': 4.5,
#   'reference': 'ChIJ5carHpNV3IgRg2sUDm8rhHY',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 874,
#   'vicinity': '19 East Main Street, Avon Park'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 27.7552978, 'lng': -81.53005929999999},
#    'viewport': {'northeast': {'lat': 27.7567173302915,
#      'lng': -81.52884091970849},
#     'southwest': {'lat': 27.75401936970849, 'lng': -81.5315388802915}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#   'icon_background_color': '#4B96F3',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#   'name': 'Dollar General',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 720,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105469111796929978314">Dollar General</a>'],
#     'photo_reference': 'AcJnMuFI7uVUJjHpsksYt20OWpiGBKU34z_Sv-J3Xu2ajU_MPml6JUfn-ZJtu0apQ_gJIijtXyNXdluHgR-C-wNc6e5_W4XsWQuUw8J_0rMDKHMMfRx5IUi4QeDGrxqC1mqJGBQGhDI05k4E4OXbJD2FGJbusDGOnXwEOtHOKndawmsB1E1L',
#     'width': 480}],
#   'place_id': 'ChIJdXmSTWsB3YgRgVNmijTNtb4',
#   'plus_code': {'compound_code': 'QF49+4X Frostproof, FL, USA',
#    'global_code': '76VWQF49+4X'},
#   'price_level': 1,
#   'rating': 4.1,
#   'reference': 'ChIJdXmSTWsB3YgRgVNmijTNtb4',
#   'scope': 'GOOGLE',
#   'types': ['drugstore',
#    'convenience_store',
#    'food',
#    'point_of_interest',
#    'health',
#    'home_goods_store',
#    'store',
#    'establishment'],
#   'user_ratings_total': 295,
#   'vicinity': '14 Highway 630 East, Frostproof'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 27.5924215, 'lng': -81.5011525},
#    'viewport': {'northeast': {'lat': 27.5937648302915,
#      'lng': -81.50010126970851},
#     'southwest': {'lat': 27.5910668697085, 'lng': -81.50279923029152}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/school-71.png',
#   'icon_background_color': '#7B9EB0',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/school_pinlet',
#   'name': 'Avon Park Middle School',
#   'opening_hours': {'open_now': False},
#   'place_id': 'ChIJ_emjjOxV3IgRXbb42RuxWGM',
#   'plus_code': {'compound_code': 'HFRX+XG Avon Park, FL, USA',
#    'global_code': '76VWHFRX+XG'},
#   'rating': 3.9,
#   'reference': 'ChIJ_emjjOxV3IgRXbb42RuxWGM',
#   'scope': 'GOOGLE',
#   'types': ['point_of_interest', 'school', 'establishment'],
#   'user_ratings_total': 19,
#   'vicinity': '401 South Lake Avenue, Avon Park'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 27.6183242, 'lng': -81.51174619999999},
#    'viewport': {'northeast': {'lat': 27.6196786802915,
#      'lng': -81.5102589197085},
#     'southwest': {'lat': 27.6169807197085, 'lng': -81.51295688029151}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'icon_background_color': '#7B9EB0',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#   'name': 'Campbell Lisa M DDS',
#   'place_id': 'ChIJZVqoQ39V3IgRHLmQNcMAnxM',
#   'plus_code': {'compound_code': 'JF9Q+88 Avon Park, FL, USA',
#    'global_code': '76VWJF9Q+88'},
#   'reference': 'ChIJZVqoQ39V3IgRHLmQNcMAnxM',
#   'scope': 'GOOGLE',
#   'types': ['dentist', 'point_of_interest', 'health', 'establishment'],
#   'vicinity': '950 County Road 17A West, Avon Park'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 27.6088029, 'lng': -81.5174983},
#    'viewport': {'northeast': {'lat': 27.6100467802915,
#      'lng': -81.5158686197085},
#     'southwest': {'lat': 27.6073488197085, 'lng': -81.5185665802915}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Subway',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 2296,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104132267849853647303">Josh Magda</a>'],
#     'photo_reference': 'AcJnMuGYg5UupusfYYz0uW0POB_Aw5KR28husSy2RVY1a9ELs4dBKy0zNE4WU9awiIBAGZCQiqhpmTM5HHdwGhkrkpTv-9adTzfeneGYJqzk4Hzeplh_yNtECsBDjE-2Woq5WpA-oSxZHFCidJWfZvPi4mi0pCloGgBIlhZUHd7efbNR7wn2',
#     'width': 4080}],
#   'place_id': 'ChIJYSCKQIhV3IgRiwG9tq-fjr0',
#   'plus_code': {'compound_code': 'JF5M+G2 Avon Park, FL, USA',
#    'global_code': '76VWJF5M+G2'},
#   'price_level': 1,
#   'rating': 4.1,
#   'reference': 'ChIJYSCKQIhV3IgRiwG9tq-fjr0',
#   'scope': 'GOOGLE',
#   'types': ['meal_takeaway',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'user_ratings_total': 165,
#   'vicinity': '1041 US Highway 27 North, Avon Park'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 27.5944239, 'lng': -81.5148169},
#    'viewport': {'northeast': {'lat': 27.5959021302915,
#      'lng': -81.5133147697085},
#     'southwest': {'lat': 27.5932041697085, 'lng': -81.51601273029151}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'icon_background_color': '#909CE1',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#   'name': 'Budget Inn of Avon Park',
#   'photos': [{'height': 4032,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110861664896685522262">Jo Ann</a>'],
#     'photo_reference': 'AcJnMuHQ2I2cuECLu52KNKJt6seQoFdyYISWTC-u4HY_b_nFmrwR1jE44KSUUPflMDtD1p9FzkcSaJitiQndmpxIRNryEy3CMRlczd5O1lCEFzf0Ug84q8Aawn6AiYRVwM64AE-9-ucQp8gNVSsrH9lMKuAob1I86P5CdqPBl5RdNW6rQtR_',
#     'width': 3024}],
#   'place_id': 'ChIJVUPqTvVV3IgRljMMdEvb3Ww',
#   'plus_code': {'compound_code': 'HFVP+Q3 Avon Park, FL, USA',
#    'global_code': '76VWHFVP+Q3'},
#   'rating': 3.2,
#   'reference': 'ChIJVUPqTvVV3IgRljMMdEvb3Ww',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 66,
#   'vicinity': '102 US Highway 27 South, Avon Park'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 27.64927299999999,
#     'lng': -81.61979889999999},
#    'viewport': {'northeast': {'lat': 27.6502362802915,
#      'lng': -81.61910061970849},
#     'southwest': {'lat': 27.64753831970849, 'lng': -81.6217985802915}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/worship_general-71.png',
#   'icon_background_color': '#7B9EB0',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/worship_christian_pinlet',
#   'name': 'Corinth Church',
#   'photos': [{'height': 3864,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112368080990031905839">LW Ridge</a>'],
#     'photo_reference': 'AcJnMuHC_cTj29_fraaChlzS2_cSji2hizyn9SkzZ0gU3EYhdHweOELJ6VYz4IIFEgBcPmLUkAJQl5Cp1WvkgJoUxQWd2W0Hm0ectDZtrDZmCxW6rCXD-wqyIvEsjEHIHTtIyReOcrPBPa-Obt1_Nk7KUaMbtzdIdX3UB4e_irhHuflX3RZV',
#     'width': 5152}],
#   'place_id': 'ChIJk1Ab9en93IgRvZ0Czi16vBs',
#   'plus_code': {'compound_code': 'J9XJ+P3 Fort Meade, FL, USA',
#    'global_code': '76VWJ9XJ+P3'},
#   'rating': 5,
#   'reference': 'ChIJk1Ab9en93IgRvZ0Czi16vBs',
#   'scope': 'GOOGLE',
#   'types': ['church',
#    'place_of_worship',
#    'point_of_interest',
#    'establishment'],
#   'user_ratings_total': 3,
#   'vicinity': 'Fort Meade'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 27.6183242, 'lng': -81.51174619999999},
#    'viewport': {'northeast': {'lat': 27.6196786802915,
#      'lng': -81.5102589197085},
#     'southwest': {'lat': 27.6169807197085, 'lng': -81.51295688029151}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/pharmacy-71.png',
#   'icon_background_color': '#F88181',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/pharmacy_pinlet',
#   'name': 'Central Fl Pharmacy',
#   'opening_hours': {'open_now': False},
#   'place_id': 'ChIJZVqoQ39V3IgRVHuBFZT8_Ks',
#   'plus_code': {'compound_code': 'JF9Q+88 Avon Park, FL, USA',
#    'global_code': '76VWJF9Q+88'},
#   'reference': 'ChIJZVqoQ39V3IgRVHuBFZT8_Ks',
#   'scope': 'GOOGLE',
#   'types': ['pharmacy',
#    'point_of_interest',
#    'health',
#    'store',
#    'establishment'],
#   'vicinity': '950 County Road 17A West, Avon Park'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 27.5976531, 'lng': -81.5149914},
#    'viewport': {'northeast': {'lat': 27.59904558029151,
#      'lng': -81.5135704697085},
#     'southwest': {'lat': 27.5963476197085, 'lng': -81.51626843029152}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/cafe-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/cafe_pinlet',
#   'name': "Dunkin'",
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 1920,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105958512475567641979">Michael Patrick (Mikey)</a>'],
#     'photo_reference': 'AcJnMuEiPpUVDN5vVQmr50xJgAf-y6Bgdzzz436FB_dTWWUrcaQ4XjmBhN5hSgS3rO-Sz3gR-oQi52ffoqOCnyLDCPOdX-NSIctrHKffNj9glaaiAYl7UmjHKZdlp5nxiDINM-aIB_mP1ZWBCjZEbaONFpHVxSOMMeMwTudgGWbMMU1zdhC-',
#     'width': 1080}],
#   'place_id': 'ChIJKW-wkYlV3IgRgw2HKF8giyU',
#   'plus_code': {'compound_code': 'HFXP+32 Avon Park, FL, USA',
#    'global_code': '76VWHFXP+32'},
#   'price_level': 1,
#   'rating': 3.8,
#   'reference': 'ChIJKW-wkYlV3IgRgw2HKF8giyU',
#   'scope': 'GOOGLE',
#   'types': ['bakery',
#    'cafe',
#    'meal_takeaway',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'store',
#    'establishment'],
#   'user_ratings_total': 625,
#   'vicinity': '201 US Highway 27 North, Avon Park'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 27.6089241, 'lng': -81.5170945},
#    'viewport': {'northeast': {'lat': 27.6101073802915,
#      'lng': -81.51566671970849},
#     'southwest': {'lat': 27.6074094197085, 'lng': -81.5183646802915}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#   'icon_background_color': '#4B96F3',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#   'name': 'Walmart Supercenter',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 600,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109647794445555514349">Walmart Supercenter</a>'],
#     'photo_reference': 'AcJnMuEdsS0yOtKlN7nd0ZGFLQmXt55o4ZjiybGnlnWKr8IgPKdRl6_q00m8d95qTiVB76KvtmJ0_5LGB95w_9bAR9GR8KSKdtZr78lmwSbIQoYY-5ZL27T8opwP3vFxxIexguMSeqiOP3DY6mlC20KWlGkKj8rpAQyBvCT-1NrKfC8p0T0h',
#     'width': 1067}],
#   'place_id': 'ChIJ-27TJO3_3IgR34inZj6w5RQ',
#   'plus_code': {'compound_code': 'JF5M+H5 Avon Park, FL, USA',
#    'global_code': '76VWJF5M+H5'},
#   'price_level': 1,
#   'rating': 4.1,
#   'reference': 'ChIJ-27TJO3_3IgR34inZj6w5RQ',
#   'scope': 'GOOGLE',
#   'types': ['department_store',
#    'hardware_store',
#    'furniture_store',
#    'grocery_or_supermarket',
#    'bakery',
#    'electronics_store',
#    'food',
#    'point_of_interest',
#    'clothing_store',
#    'home_goods_store',
#    'store',
#    'establishment'],
#   'user_ratings_total': 3398,
#   'vicinity': '1041 US Highway 27, Avon Park'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 27.5835166, 'lng': -81.5157522},
#    'viewport': {'northeast': {'lat': 27.5848889302915,
#      'lng': -81.51433941970849},
#     'southwest': {'lat': 27.5821909697085, 'lng': -81.5170373802915}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Yums Chinese Food',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3036,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111767510277636615431">Happy Heather Logue-Oleson, Orlando Realtor</a>'],
#     'photo_reference': 'AcJnMuGvzdIOBDjQG-DlwCyV1b3-_ls38MFPFEKhMsEqWnqyI0FTx72UhgIOGdiOX9WfxQVypVqy_TscmxVqRX_iPTWcMfVt3mo0-QIuVGWWolIWb4GELhNdKGjMGntpwtEej44DZ4YeHtcM8smKqDfz-jy2E4JAlQs-93NS77Fnt54C-jmH',
#     'width': 4048}],
#   'place_id': 'ChIJHcHu3YdV3IgRB0DjQRH9NYs',
#   'plus_code': {'compound_code': 'HFMM+CM Avon Park, FL, USA',
#    'global_code': '76VWHFMM+CM'},
#   'rating': 4,
#   'reference': 'ChIJHcHu3YdV3IgRB0DjQRH9NYs',
#   'scope': 'GOOGLE',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 271,
#   'vicinity': '1048 US Highway 27 South STE 1108, Avon Park'},
#  {'geometry': {'location': {'lat': 27.7458626, 'lng': -81.5306313},
#    'viewport': {'northeast': {'lat': 27.76651196597864,
#      'lng': -81.51414194102156},
#     'southwest': {'lat': 27.72932903634129, 'lng': -81.54754891853086}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/geocode-71.png',
#   'icon_background_color': '#7B9EB0',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#   'name': 'Frostproof',
#   'photos': [{'height': 1635,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103339891864974358915">ruth Smith</a>'],
#     'photo_reference': 'AcJnMuHITeln6Hstf7BlUrFcUeM8NYmbJvI4z-BHD4gtksf-KHTiMZ6V2AaktmYTs_9zSOpbrKLGMQUpctU_riBjeW-0NV_4pWWHODnPMSvTwMIIdKasCpRJci-qxPzNutp1Nai3XSo_anVcL1PJ2FdhMUTOQTnXhDzkrqb1pRWgD6KgGZnG',
#     'width': 4032}],
#   'place_id': 'ChIJEQc4l7AA3YgRzMVfDyhtL1g',
#   'reference': 'ChIJEQc4l7AA3YgRzMVfDyhtL1g',
#   'scope': 'GOOGLE',
#   'types': ['locality', 'political'],
#   'vicinity': 'Frostproof'}]

# %%
# Obtener detalles de un lugar
def get_place_details(place_id):    
    fields = 'name,formatted_address,place_id,geometry,types'
    url = "https://maps.googleapis.com/maps/api/place/details/json"
    params= f"place_id={place_id}&fields={fields}"
    response_json = request_api(url, params)
    print(response_json)
    result = response_json['result']
    return result


places_details = []
for place in places:
    place_id = place['place_id']
    place_details = get_place_details(place_id)
    places_details.append(place_details)
    break # traer solo el primero para probar
places_details
# Out:
# {'html_attributions': [], 'result': {'address_components': [{'long_name': 'Avon Park', 'short_name': 'Avon Park', 'types': ['locality', 'political']}, {'long_name': 'Highlands County', 'short_name': 'Highlands County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'Florida', 'short_name': 'FL', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '33825', 'short_name': '33825', 'types': ['postal_code']}], 'adr_address': '<span class="locality">Avon Park</span>, <span class="region">FL</span> <span class="postal-code">33825</span>, <span class="country-name">USA</span>', 'formatted_address': 'Avon Park, FL 33825, USA', 'geometry': {'location': {'lat': 27.5958672, 'lng': -81.5061862}, 'viewport': {'northeast': {'lat': 27.63315792242184, 'lng': -81.47286495262327}, 'southwest': {'lat': 27.57236998615755, 'lng': -81.53922891092547}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/geocode-71.png', 'icon_background_color': '#7B9EB0', 'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet', 'name': 'Avon Park', 'photos': [{'height': 1600, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103339891864974358915">ruth Smith</a>'], 'photo_reference': 'AcJnMuGLuyJKPKJpdqXRGaLuqnseOqk9CqU328uVwYPMtjNT0_hrIa7-r1leOAU5hh8vldlwl7KtHCiBxwHH1dkpJnuS03L4H7bCVyVe9rGVn-SI0txC3AnH9I22JNI0QpWLDj785MvoJUXgKIf9TI0AfqMeB6RzfZ4UX2GeQEcUee7Hyazo', 'width': 747}, {'height': 3582, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105788490894459740775">Joe Ivone</a>'], 'photo_reference': 'AcJnMuE4CKM4a8ccMnuELSM-4SzmziHihzmuTviGj5fAgP0ytTMhSvtw6CYntikfmq7C_a8HQrX7Zhxf8zWWQAE8LCUhxGnfDM7b-lz8jxYm_pILY_ZXCgQvK6R61VefrJdBcgGENMwjBM9cqNBM6oA8Z_tGaJicCDMHCGWGctLVzEa0Cs95', 'width': 2015}, {'height': 3000, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110907330254154897814">Lester Carignan II</a>'], 'photo_reference': 'AcJnMuHBJcwAhGtJspMs6ban6kj9sTKr8u-ipoyzMAquGVD85duidammtXp9aeJfrimJpS5wKXgJF_2JFHMCdffH9M15yt2F_iHhajM81q9JAs3kPkvps_y-CCIIrCMH2iqEJBjGhmyORWc0XvD8uZ1yAduqqbO7RNvptD-m-8PhbGDE84KE', 'width': 4000}, {'height': 3000, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110907330254154897814">Lester Carignan II</a>'], 'photo_reference': 'AcJnMuE5UBB9s_7imw08tUoyWpiRx4hvwtWiqQMHHpSH7DqdpW1iAmiA4sG3J5XuOHuqwJY_28aHUxJcwX4kEV0Hadla2KwTB69_-w6HctNDn4k49qGJVEA2om-3ScEY2_-e60KkrB8a5fRVLlrCTcR5r9Rus9VDiTrxCCKLlI1_cFPrKLVN', 'width': 4000}, {'height': 747, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103339891864974358915">ruth Smith</a>'], 'photo_reference': 'AcJnMuGXptwln_3zLFL2kyyqN9xNvJU6DrY4yHJbWLnB3mdIGOziCVkaAKxCWV_-8PRT08HtCeI4nDx53cwd12H_dCA0qtUbEJrR9Zas5UxKcPVo-bI5gQUwXhtI-0hls-nZntBHNHr1MnQy5Dh2hcIq4WWNgOA0yg6fQwuGJNr6t_2Tg-M4', 'width': 1600}, {'height': 1600, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103339891864974358915">ruth Smith</a>'], 'photo_reference': 'AcJnMuHf-fZ6gRVQcqDpxNvMypX1Pxb8Cy-3iVvl9hZEGGuZ0xUGOvXtPdVu2C8m_wcRJMmMT3O7qKw9IjWpMNOi5fP_aB2B3oyLfTGJbCXvQSbNRZydHCAp_jgpnw3Y-06XQW0KDrMro5niS0ehIQUYdhx_kDBqpLmn_trvqFZ2a-WJsv34', 'width': 747}, {'height': 4032, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105788490894459740775">Joe Ivone</a>'], 'photo_reference': 'AcJnMuEI9ybZlsNmBKbTkcBeMjIfzJjecOAbNLdFK-B1QTL7ln-EvbCoT40CTmdD2bBIFTQjoOUvwaEJNxkdFa_Ky9sjEOjzlWq-5MR3GKkKZQWQcp2SDBoxZtiPN_xRYWptPSV-srrH1YCtWjUz1vlzN_HRls-ltoL3mzVac__LHOPi5NkE', 'width': 2268}, {'height': 3120, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110907330254154897814">Lester Carignan II</a>'], 'photo_reference': 'AcJnMuH1zbxEnTrIvh8mYZKdxlIVu50AXtssOLicz6qvUaO_0AN33Sptef3YbBCiZfJc4BF7Y2jdomROz1T3JW71OqoI_4twBdC8_jhG44aOGNDQX62i4RLcKlju9GlUtDtSAjY0DyNzcmUiZaykxFeHgJuz1dqfA_bfbPz-4yfzDWTBhTRj', 'width': 41 ...
# [{'address_components': [{'long_name': 'Avon Park',
#     'short_name': 'Avon Park',
#     'types': ['locality', 'political']},
#    {'long_name': 'Highlands County',
#     'short_name': 'Highlands County',
#     'types': ['administrative_area_level_2', 'political']},
#    {'long_name': 'Florida',
#     'short_name': 'FL',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'United States',
#     'short_name': 'US',
#     'types': ['country', 'political']},
#    {'long_name': '33825', 'short_name': '33825', 'types': ['postal_code']}],
#   'adr_address': '<span class="locality">Avon Park</span>, <span class="region">FL</span> <span class="postal-code">33825</span>, <span class="country-name">USA</span>',
#   'formatted_address': 'Avon Park, FL 33825, USA',
#   'geometry': {'location': {'lat': 27.5958672, 'lng': -81.5061862},
#    'viewport': {'northeast': {'lat': 27.63315792242184,
#      'lng': -81.47286495262327},
#     'southwest': {'lat': 27.57236998615755, 'lng': -81.53922891092547}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/geocode-71.png',
#   'icon_background_color': '#7B9EB0',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#   'name': 'Avon Park',
#   'photos': [{'height': 1600,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103339891864974358915">ruth Smith</a>'],
#     'photo_reference': 'AcJnMuGLuyJKPKJpdqXRGaLuqnseOqk9CqU328uVwYPMtjNT0_hrIa7-r1leOAU5hh8vldlwl7KtHCiBxwHH1dkpJnuS03L4H7bCVyVe9rGVn-SI0txC3AnH9I22JNI0QpWLDj785MvoJUXgKIf9TI0AfqMeB6RzfZ4UX2GeQEcUee7Hyazo',
#     'width': 747},
#    {'height': 3582,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105788490894459740775">Joe Ivone</a>'],
#     'photo_reference': 'AcJnMuE4CKM4a8ccMnuELSM-4SzmziHihzmuTviGj5fAgP0ytTMhSvtw6CYntikfmq7C_a8HQrX7Zhxf8zWWQAE8LCUhxGnfDM7b-lz8jxYm_pILY_ZXCgQvK6R61VefrJdBcgGENMwjBM9cqNBM6oA8Z_tGaJicCDMHCGWGctLVzEa0Cs95',
#     'width': 2015},
#    {'height': 3000,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110907330254154897814">Lester Carignan II</a>'],
#     'photo_reference': 'AcJnMuHBJcwAhGtJspMs6ban6kj9sTKr8u-ipoyzMAquGVD85duidammtXp9aeJfrimJpS5wKXgJF_2JFHMCdffH9M15yt2F_iHhajM81q9JAs3kPkvps_y-CCIIrCMH2iqEJBjGhmyORWc0XvD8uZ1yAduqqbO7RNvptD-m-8PhbGDE84KE',
#     'width': 4000},
#    {'height': 3000,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110907330254154897814">Lester Carignan II</a>'],
#     'photo_reference': 'AcJnMuE5UBB9s_7imw08tUoyWpiRx4hvwtWiqQMHHpSH7DqdpW1iAmiA4sG3J5XuOHuqwJY_28aHUxJcwX4kEV0Hadla2KwTB69_-w6HctNDn4k49qGJVEA2om-3ScEY2_-e60KkrB8a5fRVLlrCTcR5r9Rus9VDiTrxCCKLlI1_cFPrKLVN',
#     'width': 4000},
#    {'height': 747,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103339891864974358915">ruth Smith</a>'],
#     'photo_reference': 'AcJnMuGXptwln_3zLFL2kyyqN9xNvJU6DrY4yHJbWLnB3mdIGOziCVkaAKxCWV_-8PRT08HtCeI4nDx53cwd12H_dCA0qtUbEJrR9Zas5UxKcPVo-bI5gQUwXhtI-0hls-nZntBHNHr1MnQy5Dh2hcIq4WWNgOA0yg6fQwuGJNr6t_2Tg-M4',
#     'width': 1600},
#    {'height': 1600,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103339891864974358915">ruth Smith</a>'],
#     'photo_reference': 'AcJnMuHf-fZ6gRVQcqDpxNvMypX1Pxb8Cy-3iVvl9hZEGGuZ0xUGOvXtPdVu2C8m_wcRJMmMT3O7qKw9IjWpMNOi5fP_aB2B3oyLfTGJbCXvQSbNRZydHCAp_jgpnw3Y-06XQW0KDrMro5niS0ehIQUYdhx_kDBqpLmn_trvqFZ2a-WJsv34',
#     'width': 747},
#    {'height': 4032,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105788490894459740775">Joe Ivone</a>'],
#     'photo_reference': 'AcJnMuEI9ybZlsNmBKbTkcBeMjIfzJjecOAbNLdFK-B1QTL7ln-EvbCoT40CTmdD2bBIFTQjoOUvwaEJNxkdFa_Ky9sjEOjzlWq-5MR3GKkKZQWQcp2SDBoxZtiPN_xRYWptPSV-srrH1YCtWjUz1vlzN_HRls-ltoL3mzVac__LHOPi5NkE',
#     'width': 2268},
#    {'height': 3120,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110907330254154897814">Lester Carignan II</a>'],
#     'photo_reference': 'AcJnMuH1zbxEnTrIvh8mYZKdxlIVu50AXtssOLicz6qvUaO_0AN33Sptef3YbBCiZfJc4BF7Y2jdomROz1T3JW71OqoI_4twBdC8_jhG44aOGNDQX62i4RLcKlju9GlUtDtSAjY0DyNzcmUiZaykxFeHgJuz1dqfA_bfbPz-4yfzDWTBhTRj',
#     'width': 4160},
#    {'height': 3000,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110907330254154897814">Lester Carignan II</a>'],
#     'photo_reference': 'AcJnMuEGuJ9Rk-K3JOkv24FB271lG4laCm1ufOiykpd8SaYKTMShqkPmP45ttcrbYIfqnW8WQtvV-zfgs7Dig1DFj0qBLKWawxTjRdIzTLMOFPEo1uTcemKjRkggQaAli_-stdPlJrV_XKkz3VWRD9fQ0pTkaaKNgw5988zTBnlbVutNfu03',
#     'width': 4000},
#    {'height': 4000,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111172673840758417600">Rigoberto Luis</a>'],
#     'photo_reference': 'AcJnMuFNVD1ZIvXOOeWWvyRQ8e9Gdya4D9ibpZLk1AXo2xB2-6_31dTlGQSnxOl97nBXvDtOiR4_JZRbhG3b-kSyk0b-j8JaQC91dt5MGw14EyvPw5uQOGuj-Y_6_QmbLzhbIj7gEwvJCUTGsBN_Z2XO0oXBsHTerRAyAdM-ipxxomhKh5pJ',
#     'width': 3000}],
#   'place_id': 'ChIJV-gnG45V3IgRSDUQcb3C0hw',
#   'reference': 'ChIJV-gnG45V3IgRSDUQcb3C0hw',
#   'types': ['locality', 'political'],
#   'url': 'https://maps.google.com/?q=Avon+Park,+FL+33825,+USA&ftid=0x88dc558e1b27e857:0x1cd2c2bd71103548',
#   'utc_offset': -300,
#   'vicinity': 'Avon Park',
#   'website': 'http://www.avonpark.cc/'}]

# %%
# Normalizar los datos
def normalize(places):
    parsed_places = []
    for place in places:
        place['address'] = place['vicinity']
        place['gmap_id'] = place['place_id']
        place['description'] = ''
        place['latitude'] = place['geometry']['location']['lat']
        place['longitude'] = place['geometry']['location']['lng']
        place['category'] = place['types']
        place['avg_rating'] = place.get('rating', 0)
        place['num_of_reviews'] = place.get('user_ratings_total', 0)
        place['price'] = place.get('price_level', 0)
        place['hours'] = ''
        place['state'] = 'Florida'
        place['url'] = 'https://www.google.com/maps/place//data='+place['place_id']        
        parsed_places.append(place)

    fields = ['name', 'address', 'gmap_id', 'description', 'latitude', 'longitude', 'category', 'avg_rating', 'num_of_reviews', 'price', 'hours', 'state', 'url']
    df = pd.DataFrame(parsed_places, columns=fields)
    df["category"] = df["category"].apply(lambda x: " ".join(x))
    return df

df = normalize(places)
df
# Out:
#                            name                                       address  \
# 0                     Avon Park                                     Avon Park
# 1              Kevin Sherin, MD          1006 West Pleasant Street, Avon Park
# 2         Avon Park High School               700 East Main Street, Avon Park
# 3           JNK Auto Supply Inc            195 US Highway 27 North, Avon Park
# 4            Peace River Center           950 County Road 17A West, Avon Park
# 5   South Florida State College             600 West College Drive, Avon Park
# 6                        Subway                7030 US Highway 27, Frostproof
# 7       Royal Care of Avon Park           1213 West Stratford Road, Avon Park
# 8               Jacaranda Hotel                19 East Main Street, Avon Park
# 9                Dollar General               14 Highway 630 East, Frostproof
# 10      Avon Park Middle School              401 South Lake Avenue, Avon Park
# 11          Campbell Lisa M DDS           950 County Road 17A West, Avon Park
# 12                       Subway           1041 US Highway 27 North, Avon Park
# 13      Budget Inn of Avon Park            102 US Highway 27 South, Avon Park
# 14               Corinth Church                                    Fort Meade
# 15          Central Fl Pharmacy           950 County Road 17A West, Avon Park
# 16                      Dunkin'            201 US Highway 27 North, Avon Park
# 17          Walmart Supercenter                 1041 US Highway 27, Avon Park
# 18            Yums Chinese Food  1048 US Highway 27 South STE 1108, Avon Park
# 19                   Frostproof                                    Frostproof
#
#                         gmap_id description   latitude  longitude  \
# 0   ChIJV-gnG45V3IgRSDUQcb3C0hw              27.595867 -81.506186
# 1   ChIJIS7C6UF854gRs6HvPDkbv-o              27.599535 -81.512792
# 2   ChIJcYhIUcdV3IgRKQhEFT6RBZA              27.594513 -81.487773
# 3   ChIJv5WklJJV3IgRQPjNGzVT53o              27.596914 -81.514947
# 4   ChIJB1WyCk5X3IgR0KLuOe5C6y0              27.618313 -81.511769
# 5   ChIJK7dXAwdW3IgRrbkiT8drUtE              27.570013 -81.511692
# 6   ChIJBQ0UKRcB3YgRajNYh6FWy5Q              27.733196 -81.573226
# 7   ChIJOULHoof_3IgRzpps_TBXkMI              27.628156 -81.517087
# 8   ChIJ5carHpNV3IgRg2sUDm8rhHY              27.595980 -81.501731
# 9   ChIJdXmSTWsB3YgRgVNmijTNtb4              27.755298 -81.530059
# 10  ChIJ_emjjOxV3IgRXbb42RuxWGM              27.592422 -81.501153
# 11  ChIJZVqoQ39V3IgRHLmQNcMAnxM              27.618324 -81.511746
# 12  ChIJYSCKQIhV3IgRiwG9tq-fjr0              27.608803 -81.517498
# 13  ChIJVUPqTvVV3IgRljMMdEvb3Ww              27.594424 -81.514817
# 14  ChIJk1Ab9en93IgRvZ0Czi16vBs              27.649273 -81.619799
# 15  ChIJZVqoQ39V3IgRVHuBFZT8_Ks              27.618324 -81.511746
# 16  ChIJKW-wkYlV3IgRgw2HKF8giyU              27.597653 -81.514991
# 17  ChIJ-27TJO3_3IgR34inZj6w5RQ              27.608924 -81.517094
# 18  ChIJHcHu3YdV3IgRB0DjQRH9NYs              27.583517 -81.515752
# 19  ChIJEQc4l7AA3YgRzMVfDyhtL1g              27.745863 -81.530631
#
#                                              category  avg_rating  \
# 0                                  locality political         0.0
# 1       doctor point_of_interest health establishment         5.0
# 2   secondary_school point_of_interest school esta...         3.6
# 3    car_repair point_of_interest store establishment         4.6
# 4              point_of_interest health establishment         3.4
# 5   university point_of_interest school establishment         4.5
# 6   meal_takeaway restaurant food point_of_interes...         3.7
# 7              point_of_interest health establishment         3.2
# 8             lodging point_of_interest establishment         4.5
# 9   drugstore convenience_store food point_of_inte...         4.1
# 10             point_of_interest school establishment         3.9
# 11     dentist point_of_interest health establishment         0.0
# 12  meal_takeaway restaurant food point_of_interes...         4.1
# 13            lodging point_of_interest establishment         3.2
# 14  church place_of_worship point_of_interest esta...         5.0
# 15  pharmacy point_of_interest health store establ...         0.0
# 16  bakery cafe meal_takeaway restaurant food poin...         3.8
# 17  department_store hardware_store furniture_stor...         4.1
# 18    restaurant food point_of_interest establishment         4.0
# 19                                 locality political         0.0
#
#     num_of_reviews  price hours    state  \
# 0                0      0        Florida
# 1                4      0        Florida
# 2               11      0        Florida
# 3               78      0        Florida
# 4                5      0        Florida
# 5              110      0        Florida
# 6               90      1        Florida
# 7               21      0        Florida
# 8              874      0        Florida
# 9              295      1        Florida
# 10              19      0        Florida
# 11               0      0        Florida
# 12             165      1        Florida
# 13              66      0        Florida
# 14               3      0        Florida
# 15               0      0        Florida
# 16             625      1        Florida
# 17            3398      1        Florida
# 18             271      0        Florida
# 19               0      0        Florida
#
#                                                   url
# 0   https://www.google.com/maps/place//data=ChIJV-...
# 1   https://www.google.com/maps/place//data=ChIJIS...
# 2   https://www.google.com/maps/place//data=ChIJcY...
# 3   https://www.google.com/maps/place//data=ChIJv5...
# 4   https://www.google.com/maps/place//data=ChIJB1...
# 5   https://www.google.com/maps/place//data=ChIJK7...
# 6   https://www.google.com/maps/place//data=ChIJBQ...
# 7   https://www.google.com/maps/place//data=ChIJOU...
# 8   https://www.google.com/maps/place//data=ChIJ5c...
# 9   https://www.google.com/maps/place//data=ChIJdX...
# 10  https://www.google.com/maps/place//data=ChIJ_e...
# 11  https://www.google.com/maps/place//data=ChIJZV...
# 12  https://www.google.com/maps/place//data=ChIJYS...
# 13  https://www.google.com/maps/place//data=ChIJVU...
# 14  https://www.google.com/maps/place//data=ChIJk1...
# 15  https://www.google.com/maps/place//data=ChIJZV...
# 16  https://www.google.com/maps/place//data=ChIJKW...
# 17  https://www.google.com/maps/place//data=ChIJ-2...
# 18  https://www.google.com/maps/place//data=ChIJHc...
# 19  https://www.google.com/maps/place//data=ChIJEQ...

# %%
# Convertir el DataFrame de pandas a un objeto pyarrow.Table
df = pa.Table.from_pandas(df)
# Guardar el objeto pyarrow.Table en formato Parquet
pq.write_table(df, TABLE_ID+".parquet")

# %%
# Leer el DataFrame desde el archivo Parquet
df = pd.read_parquet(TABLE_ID+".parquet")
df.head()
# Out:
#               business_id                                               date  \
# 0  7kk7PZvEeeb9fg0XgpIf1g  2013-01-05 14:52:30, 2013-01-19 14:21:37, 2013...
# 1  jl3sNS0Yg2-LN32O8H6CSg  2013-01-05 14:52:30, 2013-01-19 14:21:37, 2013...
# 2  t3aYNpAvVxKT-CfU36kZyw  2013-01-05 14:52:30, 2013-01-19 14:21:37, 2013...
# 3  obhS1T1ZlakTmR1Ke8Luag  2013-01-05 14:52:30, 2013-01-19 14:21:37, 2013...
# 4  cCLAEzDoPBzsHePs_23Kbw  2013-01-05 14:52:30, 2013-01-19 14:21:37, 2013...
#
#                                                 name  \
# 0            Patti and Allan Herbert Wellness Center
# 1                                       Hit Zone Inc
# 2  Florida International University Recreation Ce...
# 3             Coral Gables War Memorial Youth Center
# 4                     Kids Empire Miami Dolphin Mall
#
#                                      address          city state postal_code  \
# 0   1241 Dickinson Dr Coral Gables, FL 33146  Coral Gables    FL       33146
# 1            7900 SW 40th St Miami, FL 33155         Miami    FL       33155
# 2   11290 SW 12th St WRC 101 Miami, FL 33199         Miami    FL       33199
# 3   405 University Dr Coral Gables, FL 33134  Coral Gables    FL       33134
# 4  11401 NW 12th St Ste E610 Miami, FL 33172         Miami    FL       33172
#
#     latitude  longitude  stars  review_count  is_open  \
# 0  25.715676 -80.280477    4.5            31        1
# 1  25.733021 -80.323534    4.0            17        1
# 2  25.756015 -80.378090    3.5            14        1
# 3  25.741908 -80.263279    3.5            13        1
# 4  25.787996 -80.380240    3.0            23        1
#
#                                           categories
# 0                                 Recreation Centers
# 1                                 Recreation Centers
# 2                       Trainers, Recreation Centers
# 3             Parks, Playgrounds, Recreation Centers
# 4  Recreation Centers, Indoor Playcentre, Venues ...

# %%
# Guardar el dataframe en BigQuery
def df_to_bq(df, destination_table, project_id):
    """
    Guarda un dataframe de pandas en BigQuery
    """
    # convertir a string
    df = df.astype(str)
    # guardar en BigQuery
    df.to_gbq(destination_table=destination_table, project_id=project_id, if_exists="replace")

# %%
# tabla de destino
destination_table = f"{DATASET_ID}.Meta_Data_TBL"
df_to_bq(df, destination_table, GCP_PROJECT)
